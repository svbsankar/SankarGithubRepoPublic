# %% [markdown]
# <a href="https://colab.research.google.com/github/svbsankar/SankarGithubRepoPublic/blob/main/SatyaPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
// python
x = None
print(type(x))
print(x is None)
# Out:
#   File "/tmp/ipykernel_13815/1169645903.py", line 1
#     // python
#     ^
# SyntaxError: invalid syntax
