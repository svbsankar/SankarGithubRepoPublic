# %%
print("Hello World")
# Out:
# Hello World

# %%
X = "Sankar"
print(X)
# Out:
# Sankar

# %%
type(X)
# Out:
# str

# %%
X=10
Y=22.33
Z=44+55j

# %%
print(type(X))
print(type(Z))
print(type(Y))
# Out:
# <class 'int'>
# <class 'complex'>
# <class 'float'>

# %%
print(isinstance(X,int))
print(isinstance(Y,float))
print(isinstance(Z,complex))
# Out:
# True
# True
# True

# %%
print(X+Y)
# Out:
# 32.33

# %%
print(Z+X+Y)
# Out:
# (76.33+55j)

# %%
print(Z+X+Y*3)
# Out:
# (120.99+55j)

# %%
print("hi" * 3)
# Out:
# hihihi

# %%
print("Python"[0])
# Out:
# P

# %%
print("Python"[4])
# Out:
# o

# %%
print("Python"[0:5])
# Out:
# Pytho

# %%
print(len("Python"))
# Out:
# 6

# %%
name=sankar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 name=sankar
#
# NameError: name 'sankar' is not defined

# %%
name = "sankar"
print(f"Hello,{name}!")
# Out:
# Hello,sankar!

# %%
print("Hello,{}".format(name))
# Out:
# Hello,sankar

# %%
print(name.upper())
# Out:
# SANKAR

# %%
print("Sankar V B Sriapda".strip())
# Out:
# Sankar V B Sriapda

# %%
print("Sankar ".strip())
# Out:
# Sankar

# %%
print("Sankar V B Sripada".replace("Sankar","Sripada"))
# Out:
# Sripada V B Sripada

# %%
print("a,b,c".split(","))
# Out:
# ['a', 'b', 'c']

# %%
dte=["2025", "12", "14"]
date="-".join(dte)
print(date)
# Out:
# 2025-12-14

# %%
sentance = "find the world sankar"
print(sentance.find("sankar"))
# Out:
# 15

# %%
sentance = "find the world sankar dddd"
print(f"count of d is {sentance.count("d")}")
# Out:
# count of d is 6

# %%
a = "hello world"
print(a[0])
print(a[-1])
# Out:
# h
# d

# %%
a = "hello world"
print(f"string starts with hello")
# Out:
# string starts with hello

# %%
a=10
b=20
a==b
a+b
a*b
# Out:
# 200

# %%
30%11
# Out:
# 8
