# %%
print ("Hello Satya" )
# Out:
# Hello Satya

# %%
print ("Love you Satya" )
# Out:
# Love you Satya

# %%
print ("Hello Satya", "Love you Satya","You are our best guru" )
# Out:
# Hello Satya Love you Satya You are our best guru

# %%
x=10
y=5
print (x+y)
# Out:
# 15

# %%
print (type (x))
id (x)
# Out:
# <class 'int'>
# 4345372864
